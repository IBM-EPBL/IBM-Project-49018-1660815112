# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
import seaborn as sns

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("Mall_Customers.csv") 

# Preview the first 5 lines of the loaded data 
data.head()
print(data)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
sns.kdeplot(data['Age'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
sns.lineplot(data['Age'])
# Out:
# <AxesSubplot: ylabel='Age'>

# %%
import pandas as pd 
import seaborn as sns
data = pd.read_csv("Mall_Customers.csv") 
sns.barplot(data['Age'])
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(data['Age'])
# Out:
# <AxesSubplot: ylabel='Age'>

# %%
data.mean()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4292\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
data.isnull().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
data.quantile([0.1])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4292\913460851.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.quantile([0.1])
#      CustomerID   Age  Annual Income (k$)  Spending Score (1-100)
# 0.1        20.9  21.0                23.9                    13.0

# %%
data.quantile([0.1,0.5])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4292\3882816339.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.quantile([0.1,0.5])
#      CustomerID   Age  Annual Income (k$)  Spending Score (1-100)
# 0.1        20.9  21.0                23.9                    13.0
# 0.5       100.5  36.0                61.5                    50.0

# %%
data.quantile([0.1,0.9])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4292\3859651232.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.quantile([0.1,0.9])
#      CustomerID   Age  Annual Income (k$)  Spending Score (1-100)
# 0.1        20.9  21.0                23.9                    13.0
# 0.9       180.1  59.1                93.4                    87.1

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
oneh = preprocessing.OneHotEncoder()
data['Age'] = le.fit_transform(data['Age'])
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male    1                  15                      39
# 1           2    Male    3                  15                      81
# 2           3  Female    2                  16                       6
# 3           4  Female    5                  16                      77
# 4           5  Female   13                  17                      40

# %%
x = data.iloc[:,0:12]

# %%
x
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male    1                  15                      39
# 1             2    Male    3                  15                      81
# 2             3  Female    2                  16                       6
# 3             4  Female    5                  16                      77
# 4             5  Female   13                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   17                 120                      79
# 196         197  Female   27                 126                      28
# 197         198    Male   14                 126                      74
# 198         199    Male   14                 137                      18
# 199         200    Male   12                 137                      83
#
# [200 rows x 5 columns]

# %%
y = data['CustomerID']
y
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 195    196
# 196    197
# 197    198
# 198    199
# 199    200
# Name: CustomerID, Length: 200, dtype: int64

# %%
x = data.iloc[:,0:1]
from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)
x_scaled
# Out:
# array([[-1.7234121 ],
#        [-1.70609137],
#        [-1.68877065],
#        [-1.67144992],
#        [-1.6541292 ],
#        [-1.63680847],
#        [-1.61948775],
#        [-1.60216702],
#        [-1.5848463 ],
#        [-1.56752558],
#        [-1.55020485],
#        [-1.53288413],
#        [-1.5155634 ],
#        [-1.49824268],
#        [-1.48092195],
#        [-1.46360123],
#        [-1.4462805 ],
#        [-1.42895978],
#        [-1.41163905],
#        [-1.39431833],
#        [-1.3769976 ],
#        [-1.35967688],
#        [-1.34235616],
#        [-1.32503543],
#        [-1.30771471],
#        [-1.29039398],
#        [-1.27307326],
#        [-1.25575253],
#        [-1.23843181],
#        [-1.22111108],
#        [-1.20379036],
#        [-1.18646963],
#        [-1.16914891],
#        [-1.15182818],
#        [-1.13450746],
#        [-1.11718674],
#        [-1.09986601],
#        [-1.08254529],
#        [-1.06522456],
#        [-1.04790384],
#        [-1.03058311],
#        [-1.01326239],
#        [-0.99594166],
#        [-0.97862094],
#        [-0.96130021],
#        [-0.94397949],
#        [-0.92665877],
#        [-0.90933804],
#        [-0.89201732],
#        [-0.87469659],
#        [-0.85737587],
#        [-0.84005514],
#        [-0.82273442],
#        [-0.80541369],
#        [-0.78809297],
#        [-0.77077224],
#        [-0.75345152],
#        [-0.73613079],
#        [-0.71881007],
#        [-0.70148935],
#        [-0.68416862],
#        [-0.6668479 ],
#        [-0.64952717],
#        [-0.63220645],
#        [-0.61488572],
#        [-0.597565  ],
#        [-0.58024427],
#        [-0.56292355],
#        [-0.54560282],
#        [-0.5282821 ],
#        [-0.51096138],
#        [-0.49364065],
#        [-0.47631993],
#        [-0.4589992 ],
#        [-0.44167848],
#        [-0.42435775],
#        [-0.40703703],
#        [-0.3897163 ],
#        [-0.37239558],
#        [-0.35507485],
#        [-0.33775413],
#        [-0.3204334 ],
#        [-0.30311268],
#        [-0.28579196],
#        [-0.26847123],
#        [-0.25115051],
#        [-0.23382978],
#        [-0.21650906],
#        [-0.19918833],
#        [-0.18186761],
#        [-0.16454688],
#        [-0.14722616],
#        [-0.12990543],
#        [-0.11258471],
#        [-0.09526399],
#        [-0.07794326],
#        [-0.06062254],
#        [-0.04330181],
#        [-0.02598109],
#        [-0.00866036],
#        [ 0.00866036],
#        [ 0.02598109],
#        [ 0.04330181],
#        [ 0.06062254],
#        [ 0.07794326],
#        [ 0.09526399],
#        [ 0.11258471],
#        [ 0.12990543],
#        [ 0.14722616],
#        [ 0.16454688],
#        [ 0.18186761],
#        [ 0.19918833],
#        [ 0.21650906],
#        [ 0.23382978],
#        [ 0.25115051],
#        [ 0.26847123],
#        [ 0.28579196],
#        [ 0.30311268],
#        [ 0.3204334 ],
#        [ 0.33775413],
#        [ 0.35507485],
#        [ 0.37239558],
#        [ 0.3897163 ],
#        [ 0.40703703],
#        [ 0.42435775],
#        [ 0.44167848],
#        [ 0.4589992 ],
#        [ 0.47631993],
#        [ 0.49364065],
#        [ 0.51096138],
#        [ 0.5282821 ],
#        [ 0.54560282],
#        [ 0.56292355],
#        [ 0.58024427],
#        [ 0.597565  ],
#        [ 0.61488572],
#        [ 0.63220645],
#        [ 0.64952717],
#        [ 0.6668479 ],
#        [ 0.68416862],
#        [ 0.70148935],
#        [ 0.71881007],
#        [ 0.73613079],
#        [ 0.75345152],
#        [ 0.77077224],
#        [ 0.78809297],
#        [ 0.80541369],
#        [ 0.82273442],
#        [ 0.84005514],
#        [ 0.85737587],
#        [ 0.87469659],
#        [ 0.89201732],
#        [ 0.90933804],
#        [ 0.92665877],
#        [ 0.94397949],
#        [ 0.96130021],
#        [ 0.97862094],
#        [ 0.99594166],
#        [ 1.01326239],
#        [ 1.03058311],
#        [ 1.04790384],
#        [ 1.06522456],
#        [ 1.08254529],
#        [ 1.09986601],
#        [ 1.11718674],
#        [ 1.13450746],
#        [ 1.15182818],
#        [ 1.16914891],
#        [ 1.18646963],
#        [ 1.20379036],
#        [ 1.22111108],
#        [ 1.23843181],
#        [ 1.25575253],
#        [ 1.27307326],
#        [ 1.29039398],
#        [ 1.30771471],
#        [ 1.32503543],
#        [ 1.34235616],
#        [ 1.35967688],
#        [ 1.3769976 ],
#        [ 1.39431833],
#        [ 1.41163905],
#        [ 1.42895978],
#        [ 1.4462805 ],
#        [ 1.46360123],
#        [ 1.48092195],
#        [ 1.49824268],
#        [ 1.5155634 ],
#        [ 1.53288413],
#        [ 1.55020485],
#        [ 1.56752558],
#        [ 1.5848463 ],
#        [ 1.60216702],
#        [ 1.61948775],
#        [ 1.63680847],
#        [ 1.6541292 ],
#        [ 1.67144992],
#        [ 1.68877065],
#        [ 1.70609137],
#        [ 1.7234121 ]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled,y ,test_size = 0.3, random_state = 0)
x_train
# Out:
# array([[ 0.54560282],
#        [-0.06062254],
#        [ 1.41163905],
#        [-1.39431833],
#        [ 0.92665877],
#        [-0.12990543],
#        [-0.78809297],
#        [ 1.09986601],
#        [-0.84005514],
#        [-0.23382978],
#        [ 0.68416862],
#        [-0.16454688],
#        [ 0.64952717],
#        [ 0.02598109],
#        [ 0.77077224],
#        [-0.18186761],
#        [ 0.16454688],
#        [-1.48092195],
#        [-1.25575253],
#        [ 0.71881007],
#        [ 1.5155634 ],
#        [-0.92665877],
#        [ 0.6668479 ],
#        [ 1.6541292 ],
#        [ 0.14722616],
#        [-0.64952717],
#        [-1.68877065],
#        [-0.70148935],
#        [ 0.63220645],
#        [ 1.68877065],
#        [-0.97862094],
#        [-1.55020485],
#        [ 1.63680847],
#        [-0.4589992 ],
#        [ 1.67144992],
#        [ 1.35967688],
#        [ 1.30771471],
#        [ 0.4589992 ],
#        [-0.11258471],
#        [ 0.21650906],
#        [ 1.01326239],
#        [ 1.5848463 ],
#        [-0.85737587],
#        [-1.7234121 ],
#        [-0.09526399],
#        [ 0.18186761],
#        [-0.07794326],
#        [-0.61488572],
#        [ 1.16914891],
#        [-1.01326239],
#        [-0.5282821 ],
#        [-0.87469659],
#        [-0.89201732],
#        [-0.25115051],
#        [-1.49824268],
#        [ 1.06522456],
#        [-1.32503543],
#        [ 1.49824268],
#        [ 0.61488572],
#        [-1.3769976 ],
#        [-1.46360123],
#        [-0.37239558],
#        [ 0.07794326],
#        [-0.82273442],
#        [ 0.00866036],
#        [-0.40703703],
#        [-1.67144992],
#        [ 0.28579196],
#        [ 1.11718674],
#        [ 1.70609137],
#        [-1.61948775],
#        [-0.54560282],
#        [-0.26847123],
#        [ 0.37239558],
#        [ 0.96130021],
#        [ 1.23843181],
#        [ 0.97862094],
#        [-0.14722616],
#        [ 1.7234121 ],
#        [-1.53288413],
#        [ 0.33775413],
#        [ 0.04330181],
#        [-1.11718674],
#        [-0.73613079],
#        [-0.597565  ],
#        [-1.70609137],
#        [ 0.35507485],
#        [ 1.08254529],
#        [-0.99594166],
#        [ 0.09526399],
#        [ 0.56292355],
#        [ 1.27307326],
#        [-1.42895978],
#        [-1.06522456],
#        [ 0.58024427],
#        [-0.80541369],
#        [ 0.99594166],
#        [ 0.49364065],
#        [-1.13450746],
#        [-1.23843181],
#        [ 0.25115051],
#        [ 0.89201732],
#        [-1.18646963],
#        [ 1.15182818],
#        [ 0.47631993],
#        [ 1.32503543],
#        [-1.16914891],
#        [ 0.73613079],
#        [ 1.20379036],
#        [ 0.82273442],
#        [-1.22111108],
#        [-0.00866036],
#        [-0.30311268],
#        [-0.35507485],
#        [ 0.26847123],
#        [ 0.84005514],
#        [ 1.61948775],
#        [-0.47631993],
#        [-0.3897163 ],
#        [-1.29039398],
#        [ 1.13450746],
#        [-0.3204334 ],
#        [ 1.53288413],
#        [ 1.29039398],
#        [ 1.56752558],
#        [-1.04790384],
#        [-0.71881007],
#        [ 0.70148935],
#        [-0.19918833],
#        [-0.51096138],
#        [-0.21650906],
#        [-1.09986601],
#        [-1.35967688],
#        [-1.56752558],
#        [ 0.06062254],
#        [-0.56292355],
#        [ 1.60216702],
#        [ 0.30311268],
#        [-0.90933804],
#        [ 1.25575253]])

# %%
x_train
# Out:
# array([[ 0.54560282],
#        [-0.06062254],
#        [ 1.41163905],
#        [-1.39431833],
#        [ 0.92665877],
#        [-0.12990543],
#        [-0.78809297],
#        [ 1.09986601],
#        [-0.84005514],
#        [-0.23382978],
#        [ 0.68416862],
#        [-0.16454688],
#        [ 0.64952717],
#        [ 0.02598109],
#        [ 0.77077224],
#        [-0.18186761],
#        [ 0.16454688],
#        [-1.48092195],
#        [-1.25575253],
#        [ 0.71881007],
#        [ 1.5155634 ],
#        [-0.92665877],
#        [ 0.6668479 ],
#        [ 1.6541292 ],
#        [ 0.14722616],
#        [-0.64952717],
#        [-1.68877065],
#        [-0.70148935],
#        [ 0.63220645],
#        [ 1.68877065],
#        [-0.97862094],
#        [-1.55020485],
#        [ 1.63680847],
#        [-0.4589992 ],
#        [ 1.67144992],
#        [ 1.35967688],
#        [ 1.30771471],
#        [ 0.4589992 ],
#        [-0.11258471],
#        [ 0.21650906],
#        [ 1.01326239],
#        [ 1.5848463 ],
#        [-0.85737587],
#        [-1.7234121 ],
#        [-0.09526399],
#        [ 0.18186761],
#        [-0.07794326],
#        [-0.61488572],
#        [ 1.16914891],
#        [-1.01326239],
#        [-0.5282821 ],
#        [-0.87469659],
#        [-0.89201732],
#        [-0.25115051],
#        [-1.49824268],
#        [ 1.06522456],
#        [-1.32503543],
#        [ 1.49824268],
#        [ 0.61488572],
#        [-1.3769976 ],
#        [-1.46360123],
#        [-0.37239558],
#        [ 0.07794326],
#        [-0.82273442],
#        [ 0.00866036],
#        [-0.40703703],
#        [-1.67144992],
#        [ 0.28579196],
#        [ 1.11718674],
#        [ 1.70609137],
#        [-1.61948775],
#        [-0.54560282],
#        [-0.26847123],
#        [ 0.37239558],
#        [ 0.96130021],
#        [ 1.23843181],
#        [ 0.97862094],
#        [-0.14722616],
#        [ 1.7234121 ],
#        [-1.53288413],
#        [ 0.33775413],
#        [ 0.04330181],
#        [-1.11718674],
#        [-0.73613079],
#        [-0.597565  ],
#        [-1.70609137],
#        [ 0.35507485],
#        [ 1.08254529],
#        [-0.99594166],
#        [ 0.09526399],
#        [ 0.56292355],
#        [ 1.27307326],
#        [-1.42895978],
#        [-1.06522456],
#        [ 0.58024427],
#        [-0.80541369],
#        [ 0.99594166],
#        [ 0.49364065],
#        [-1.13450746],
#        [-1.23843181],
#        [ 0.25115051],
#        [ 0.89201732],
#        [-1.18646963],
#        [ 1.15182818],
#        [ 0.47631993],
#        [ 1.32503543],
#        [-1.16914891],
#        [ 0.73613079],
#        [ 1.20379036],
#        [ 0.82273442],
#        [-1.22111108],
#        [-0.00866036],
#        [-0.30311268],
#        [-0.35507485],
#        [ 0.26847123],
#        [ 0.84005514],
#        [ 1.61948775],
#        [-0.47631993],
#        [-0.3897163 ],
#        [-1.29039398],
#        [ 1.13450746],
#        [-0.3204334 ],
#        [ 1.53288413],
#        [ 1.29039398],
#        [ 1.56752558],
#        [-1.04790384],
#        [-0.71881007],
#        [ 0.70148935],
#        [-0.19918833],
#        [-0.51096138],
#        [-0.21650906],
#        [-1.09986601],
#        [-1.35967688],
#        [-1.56752558],
#        [ 0.06062254],
#        [-0.56292355],
#        [ 1.60216702],
#        [ 0.30311268],
#        [-0.90933804],
#        [ 1.25575253]])

# %%
y_train
# Out:
# 131    132
# 96      97
# 181    182
# 19      20
# 153    154
#       ...
# 67      68
# 192    193
# 117    118
# 47      48
# 172    173
# Name: CustomerID, Length: 140, dtype: int64
